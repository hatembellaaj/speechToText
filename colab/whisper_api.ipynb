# %%
{
 "cells": [
  {
   "cell_type": "code",
   "source": [
    "!pip install openai-whisper flask pyngrok\n",
    "\n",
    "import whisper\n",
    "from flask import Flask, request, jsonify\n",
    "from pyngrok import ngrok\n",
    "\n",
    "app = Flask(__name__)\n",
    "model = whisper.load_model('small')  # Modèle de transcription\n",
    "\n",
    "@app.route('/transcribe', methods=['POST'])\n",
    "def transcribe_audio():\n",
    "    audio_file = request.files['audio']\n",
    "    audio_path = 'temp_audio.wav'\n",
    "    audio_file.save(audio_path)\n",
    "    result = model.transcribe(audio_path, language='fr')\n",
    "    return jsonify({'text': result['text']})\n",
    "\n",
    "# Lancement du serveur via ngrok\n",
    "public_url = ngrok.connect(5000)\n",
    "print('API disponible à :', public_url)\n",
    "app.run(port=5000)"
   ],
   "metadata": {},
   "outputs": [],
   "execution_count": null
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 30
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "source": [
#       6     "!pip install openai-whisper flask pyngrok\n",
#       7     "\n",
#       8     "import whisper\n",
#       9     "from flask import Flask, request, jsonify\n",
#      10     "from pyngrok import ngrok\n",
#      11     "\n",
#      12     "app = Flask(__name__)\n",
#      13     "model = whisper.load_model('small')  # Modèle de transcription\n",
#      14     "\n",
#      15     "@app.route('/transcribe', methods=['POST'])\n",
#      16     "def transcribe_audio():\n",
#      17     "    audio_file = request.files['audio']\n",
#      18     "    audio_path = 'temp_audio.wav'\n",
#      19     "    audio_file.save(audio_path)\n",
#      20     "    result = model.transcribe(audio_path, language='fr')\n",
#      21     "    return jsonify({'text': result['text']})\n",
#      22     "\n",
#      23     "# Lancement du serveur via ngrok\n",
#      24     "public_url = ngrok.connect(5000)\n",
#      25     "print('API disponible à :', public_url)\n",
#      26     "app.run(port=5000)"
#      27    ],
#      28    "metadata": {},
#      29    "outputs": [],
# ---> 30    "execution_count": null
#      31   }
#      32  ],
#      33  "metadata": {},
#      34  "nbformat": 4,
#      35  "nbformat_minor": 2
#      36 }
#
# NameError: name 'null' is not defined
